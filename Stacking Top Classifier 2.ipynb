# %%
import numpy as np
np.random.seed(1019)

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import xgboost

import sklearn
from sklearn.model_selection import train_test_split 

import sys, os, gc, types
import time
from subprocess import check_output

# %%
sys.path.append('./utils')

from training import cv, train
from plotting import plot_importance
from data import Data

# %%
root_paths = [
    "/data/kaggle-instacart",
    "/Users/jiayou/Dropbox/珺珺的程序/Kaggle/Instacart",
    "/Users/jiayou/Dropbox/Documents/珺珺的程序/Kaggle/Instacart"
]
root = None
for p in root_paths:
    if os.path.exists(p):
        root = p
        break

# %%
name = 'v13-t0'


down_sample = None
folds=5
aug=True
num_searches=5

boosting_rounds = 400
# stopping_rounds = 10

# %% [markdown]
# ----

# %% [markdown]
# # xgb top model training and prediction

# %%
train_all = Data.train(down_sample=down_sample, aug=aug)

test_all = Data.test(down_sample=down_sample)
# Out:
# Load orig data starts...
# ./utils/data.py:118: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df[col] = df[col].astype(np.float32)
# /usr/local/lib/python3.5/dist-packages/pandas/core/frame.py:2746: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   **kwargs)
# Load orig data: 78.69s
# Load aug data starts...
# Loaded 10 aug shards
# Loaded 20 aug shards
# Loaded 30 aug shards
# Loaded 40 aug shards
# Loaded 50 aug shards
# Loaded 60 aug shards
# Load aug data: 172.79s

# %%
train_df = train_all.copy()
test = test_all.copy()

bnames = ['v13-b{}'.format(i) for i in range(2)]

# Load data with reorder prob - 6 prediction csv files
# merge reorder prob to train_df
for bname in bnames:
    pred=[]
    for i in range(folds):
        pred.append(pd.read_csv(os.path.join(root, 'stacking', 'val_prediction.{}.cv{}.csv'.format(bname, i))))
        pred[i].rename(columns={'reorder_prob':bname}, inplace=True)

    pred_df = pd.concat([pred[i] for i in range(folds)])
    train_df = train_df.merge(pred_df, on=['order_id','product_id'], how='left')

    # merge reorder prob to test
    pred_t_df = pd.read_csv(os.path.join(root, 'stacking', 'test_prediction.{}.csv'.format(bname)))
    pred_t_df.rename(columns={'reordered':bname}, inplace=True)
    test = test.merge(pred_t_df, on=['order_id','product_id'], how='left')

test.sort_index(axis=1, inplace=True)
dtest = xgboost.DMatrix(test.drop(['eval_set', 'order_id', 'reordered', 'product_id'], axis=1))

# %%
pred_t = None
for i in range(num_searches):
    X_train, X_val, y_train, y_val = train_test_split(
        train_df.drop(['eval_set', 'product_id', 'order_id', 'reordered'], axis=1),
        train_df.reordered,
        test_size=0.01, random_state=np.random.randint(0, 10000))

    X_train.sort_index(axis=1, inplace=True)
    X_val.sort_index(axis=1, inplace=True)

    dtrain = xgboost.DMatrix(X_train, y_train)
    dval = xgboost.DMatrix(X_val, y_val)

    gc.collect()
    print(dtrain.num_row(), dtrain.num_col())
    print(dval.num_row(), dval.num_col())

    xgb_params = {
        "booster"          : "gbtree",
        "tree_method"      : "hist",
        "learning_rate"    : 0.05,
        "max_depth"        : 5,
        "min_child_weight" : 10, # hessian weight
        "subsample"        : 0.7,
        "colsample_bytree" : 0.9,

        "objective"        : "reg:logistic",
        "eval_metric"      : "logloss",

        "min_split_loss"   : 0.7, # ?
        "reg_alpha"        : 2e-05,
        "reg_lambda"       : 10,
        "seed"             : np.random.randint(0, 10000)
    #     "grow_policy"      : ["lossguide"]
    }
    
    print(xgb_params)
    
    bst = train(
        xgb_params, dtrain, num_boost_round=boosting_rounds,
        evals=[(dtrain, 'train'), (dval, 'val')])
#         callbacks=[
#                 xgboost.callback.early_stop(stopping_rounds=stopping_rounds)
#         ])

    _, axes = plt.subplots(nrows=1, ncols=5, figsize=(25,18))
    measures = ['weight', 'gain', 'cover']
    for i in range(3):
        plot_importance(bst, height=1, ax=axes[2*i], importance_type=measures[i], title=measures[i])
    plt.show()


    if pred_t is None:
        pred_t = bst.predict(dtest)
    else:
        pred_t += bst.predict(dtest)

pred_t = pred_t / num_searches

test_result = pd.DataFrame({'order_id':test.order_id,'product_id':test.product_id, 'reordered':pred_t})
test_result.to_csv(os.path.join(root, 'stacking', 'test_prediction.{}.csv'.format(name)), index=False)
# Out:
# 20294360 90
# 204994 90
# {'tree_method': 'hist', 'reg_alpha': 2e-05, 'learning_rate': 0.05, 'colsample_bytree': 0.9, 'min_child_weight': 10, 'eval_metric': 'logloss', 'seed': 6584, 'min_split_loss': 0.7, 'booster': 'gbtree', 'reg_lambda': 10, 'max_depth': 5, 'subsample': 0.7, 'objective': 'reg:logistic'}
# Round 0 update starts...
# Round 0 update: 58.88s
# Round 0 eval starts...
# Round 0 eval: 0.09s
# [0]	train-logloss:0.657863	val-logloss:0.657862
# Round 1 update starts...
# Round 1 update: 2.38s
# Round 1 eval starts...
# Round 1 eval: 0.06s
# [1]	train-logloss:0.625952	val-logloss:0.625951
# Round 2 update starts...
# Round 2 update: 2.37s
# Round 2 eval starts...
# Round 2 eval: 0.05s
# [2]	train-logloss:0.596972	val-logloss:0.596971
# Round 3 update starts...
# Round 3 update: 2.34s
# Round 3 eval starts...
# Round 3 eval: 0.05s
# [3]	train-logloss:0.57057	val-logloss:0.570569
# Round 4 update starts...
# Round 4 update: 2.36s
# Round 4 eval starts...
# Round 4 eval: 0.05s
# [4]	train-logloss:0.546442	val-logloss:0.54644
# Round 5 update starts...
# Round 5 update: 2.35s
# Round 5 eval starts...
# Round 5 eval: 0.05s
# [5]	train-logloss:0.524339	val-logloss:0.524338
# Round 6 update starts...
# Round 6 update: 2.32s
# Round 6 eval starts...
# Round 6 eval: 0.06s
# [6]	train-logloss:0.50404	val-logloss:0.504037
# Round 7 update starts...
# Round 7 update: 2.37s
# Round 7 eval starts...
# Round 7 eval: 0.06s
# [7]	train-logloss:0.485365	val-logloss:0.48536
# Round 8 update starts...
# Round 8 update: 2.37s
# Round 8 eval starts...
# Round 8 eval: 0.05s
# [8]	train-logloss:0.468149	val-logloss:0.468142
# Round 9 update starts...
# Round 9 update: 2.37s
# Round 9 eval starts...
# Round 9 eval: 0.06s
# [9]	train-logloss:0.452258	val-logloss:0.45225
# Round 10 update starts...
# Round 10 update: 2.35s
# Round 10 eval starts...
# Round 10 eval: 0.06s
# [10]	train-logloss:0.437562	val-logloss:0.437554
# Round 11 update starts...
# Round 11 update: 2.37s
# Round 11 eval starts...
# Round 11 eval: 0.06s
# [11]	train-logloss:0.423963	val-logloss:0.423951
# Round 12 update starts...
# Round 12 update: 2.42s
# Round 12 eval starts...
# Round 12 eval: 0.05s
# [12]	train-logloss:0.411361	val-logloss:0.41135
# Round 13 update starts...
# Round 13 update: 2.39s
# Round 13 eval starts...
# Round 13 eval: 0.05s
# [13]	train-logloss:0.399669	val-logloss:0.399655
# Round 14 update starts...
# Round 14 update: 2.41s
# Round 14 eval starts...
# Round 14 eval: 0.05s
# [14]	train-logloss:0.388815	val-logloss:0.388798
# Round 15 update starts...
# Round 15 update: 2.39s
# Round 15 eval starts...
# Round 15 eval: 0.05s
# [15]	train-logloss:0.378729	val-logloss:0.37871
# Round 16 update starts...
# Round 16 update: 2.40s
# Round 16 eval starts...
# Round 16 eval: 0.05s
# [16]	train-logloss:0.369351	val-logloss:0.36933
# Round 17 update starts...
# Round 17 update: 2.40s
# Round 17 eval starts...
# Round 17 eval: 0.05s
# [17]	train-logloss:0.360625	val-logloss:0.360601
# Round 18 update starts...
# Round 18 update: 2.41s
# Round 18 eval starts...
# Round 18 eval: 0.05s
# [18]	train-logloss:0.352502	val-logloss:0.352476
# Round 19 update starts...
# Round 19 update: 2.39s
# Round 19 eval starts...
# Round 19 eval: 0.05s
# [19]	train-logloss:0.344936	val-logloss:0.344908
# Round 20 update starts...
# Round 20 update: 2.46s
# Round 20 eval starts...
# Round 20 eval: 0.05s
# [20]	train-logloss:0.337888	val-logloss:0.337858
# Round 21 update starts...
# Round 21 update: 2.47s
# Round 21 eval starts...
# Round 21 eval: 0.05s
# [21]	train-logloss:0.331314	val-logloss:0.331282
# Round 22 update starts...
# Round 22 update: 2.37s
# Round 22 eval starts...
# Round 22 eval: 0.05s
# [22]	train-logloss:0.325355	val-logloss:0.325326
# Round 23 update starts...
# Round 23 update: 2.45s
# Round 23 eval starts...
# Round 23 eval: 0.05s
# [23]	train-logloss:0.319624	val-logloss:0.319593
# Round 24 update starts...
# Round 24 update: 2.48s
# Round 24 eval starts...
# Round 24 eval: 0.05s
# [24]	train-logloss:0.314279	val-logloss:0.314246
# Round 25 update starts...
# Round 25 update: 2.51s
# Round 25 eval starts...
# Round 25 eval: 0.05s
# [25]	train-logloss:0.309291	val-logloss:0.309255
# Round 26 update starts...
# Round 26 update: 2.49s
# Round 26 eval starts...
# Round 26 eval: 0.05s
# [26]	train-logloss:0.304632	val-logloss:0.304595
# Round 27 update starts...
# Round 27 update: 2.49s
# Round 27 eval starts...
# Round 27 eval: 0.05s
# [27]	train-logloss:0.300283	val-logloss:0.300244
# Round 28 update starts...
# Round 28 update: 2.50s
# Round 28 eval starts...
# Round 28 eval: 0.05s
# [28]	train-logloss:0.296222	val-logloss:0.29618
# Round 29 update starts...
# Round 29 update: 2.47s
# Round 29 eval starts...
# Round 29 eval: 0.05s
# [29]	train-logloss:0.292432	val-logloss:0.292389
# Round 30 update starts...
# Round 30 update: 2.47s
# Round 30 eval starts...
# Round 30 eval: 0.05s
# [30]	train-logloss:0.288893	val-logloss:0.288849
# Round 31 update starts...
# Round 31 update: 2.50s
# Round 31 eval starts...
# Round 31 eval: 0.05s
# [31]	train-logloss:0.285584	val-logloss:0.285538
# Round 32 update starts...
# Round 32 update: 2.52s
# Round 32 eval starts...
# Round 32 eval: 0.05s
# [32]	train-logloss:0.282494	val-logloss:0.282447
# Round 33 update starts...
# Round 33 update: 2.49s
# Round 33 eval starts...
# Round 33 eval: 0.05s
# [33]	train-logloss:0.279609	val-logloss:0.279561
# Round 34 update starts...
# Round 34 update: 2.50s
# Round 34 eval starts...
# Round 34 eval: 0.05s
# [34]	train-logloss:0.276915	val-logloss:0.276865
# Round 35 update starts...
# Round 35 update: 2.53s
# Round 35 eval starts...
# Round 35 eval: 0.05s
# [35]	train-logloss:0.274398	val-logloss:0.274347
# Round 36 update starts...
# Round 36 update: 2.46s
# Round 36 eval starts...
# Round 36 eval: 0.05s
# [36]	train-logloss:0.272049	val-logloss:0.271996
# Round 37 update starts...
# Round 37 update: 2.51s
# Round 37 eval starts...
# Round 37 eval: 0.05s
# [37]	train-logloss:0.269854	val-logloss:0.269799
# Round 38 update starts...
# Round 38 update: 2.49s
# Round 38 eval starts...
# Round 38 eval: 0.05s
# [38]	train-logloss:0.267805	val-logloss:0.267749
# Round 39 update starts...
# Round 39 update: 2.57s
# Round 39 eval starts...
# Round 39 eval: 0.05s
# [39]	train-logloss:0.265893	val-logloss:0.265837
# Round 40 update starts...
# Round 40 update: 2.53s
# Round 40 eval starts...
# Round 40 eval: 0.05s
# [40]	train-logloss:0.264107	val-logloss:0.26405
# Round 41 update starts...
# Round 41 update: 2.52s
# Round 41 eval starts...
# Round 41 eval: 0.05s
# [41]	train-logloss:0.262441	val-logloss:0.262384
# Round 42 update starts...
# Round 42 update: 2.54s
# Round 42 eval starts...
# Round 42 eval: 0.05s
# [42]	train-logloss:0.260885	val-logloss:0.260828
# Round 43 update starts...
# Round 43 update: 2.62s
# Round 43 eval starts...
# Round 43 eval: 0.05s
# [43]	train-logloss:0.259435	val-logloss:0.259377
# Round 44 update starts...
# Round 44 update: 2.55s
# Round 44 eval starts...
# Round 44 eval: 0.05s
# [44]	train-logloss:0.258082	val-logloss:0.258022
# Round 45 update starts...
# Round 45 update: 2.52s
# Round 45 eval starts...
# Round 45 eval: 0.05s
# [45]	train-logloss:0.256819	val-logloss:0.256759
# Round 46 update starts...
# Round 46 update: 2.56s
# Round 46 eval starts...
# Round 46 eval: 0.05s
# [46]	train-logloss:0.255641	val-logloss:0.25558
# Round 47 update starts...
# Round 47 update: 2.55s
# Round 47 eval starts...
# Round 47 eval: 0.05s
# [47]	train-logloss:0.254544	val-logloss:0.254483
# Round 48 update starts...
# Round 48 update: 2.70s
# Round 48 eval starts...
# Round 48 eval: 0.05s
# [48]	train-logloss:0.253522	val-logloss:0.25346
# Round 49 update starts...
# Round 49 update: 2.56s
# Round 49 eval starts...
# Round 49 eval: 0.05s
# [49]	train-logloss:0.252568	val-logloss:0.252507
# Round 50 update starts...
# Round 50 update: 2.58s
# Round 50 eval starts...
# Round 50 eval: 0.05s
# [50]	train-logloss:0.25168	val-logloss:0.251619
# Round 51 update starts...
# Round 51 update: 2.58s
# Round 51 eval starts...
# Round 51 eval: 0.05s
# [51]	train-logloss:0.250852	val-logloss:0.250793
# Round 52 update starts...
# Round 52 update: 2.57s
# Round 52 eval starts...
# Round 52 eval: 0.05s
# [52]	train-logloss:0.250082	val-logloss:0.250023
# Round 53 update starts...
# Round 53 update: 2.55s
# Round 53 eval starts...
# Round 53 eval: 0.05s
# [53]	train-logloss:0.249365	val-logloss:0.249307
# Round 54 update starts...
# Round 54 update: 2.58s
# Round 54 eval starts...
# Round 54 eval: 0.05s
# [54]	train-logloss:0.248698	val-logloss:0.248641
# Round 55 update starts...
# Round 55 update: 2.55s
# Round 55 eval starts...
# Round 55 eval: 0.05s
# [55]	train-logloss:0.248077	val-logloss:0.248019
# Round 56 update starts...
# Round 56 update: 2.56s
# Round 56 eval starts...
# Round 56 eval: 0.05s
# [56]	train-logloss:0.2475	val-logloss:0.247443
# Round 57 update starts...
# Round 57 update: 2.60s
# Round 57 eval starts...
# Round 57 eval: 0.05s
# [57]	train-logloss:0.246963	val-logloss:0.246907
# Round 58 update starts...
# Round 58 update: 2.56s
# Round 58 eval starts...
# Round 58 eval: 0.05s
# [58]	train-logloss:0.246464	val-logloss:0.246409
# Round 59 update starts...
# Round 59 update: 2.59s
# Round 59 eval starts...
# Round 59 eval: 0.05s
# [59]	train-logloss:0.245999	val-logloss:0.245945
# Round 60 update starts...
# Round 60 update: 2.56s
# Round 60 eval starts...
# Round 60 eval: 0.05s
# [60]	train-logloss:0.245568	val-logloss:0.245514
# Round 61 update starts...
# Round 61 update: 2.60s
# Round 61 eval starts...
# Round 61 eval: 0.05s
# [61]	train-logloss:0.245167	val-logloss:0.245115
# Round 62 update starts...
# Round 62 update: 2.56s
# Round 62 eval starts...
# Round 62 eval: 0.05s
# [62]	train-logloss:0.244795	val-logloss:0.244744
# Round 63 update starts...
# Round 63 update: 2.53s
# Round 63 eval starts...
# Round 63 eval: 0.05s
# [63]	train-logloss:0.24445	val-logloss:0.244401
# Round 64 update starts...
# Round 64 update: 2.52s
# Round 64 eval starts...
# Round 64 eval: 0.05s
# [64]	train-logloss:0.244129	val-logloss:0.244081
# Round 65 update starts...
# Round 65 update: 2.57s
# Round 65 eval starts...
# Round 65 eval: 0.05s
# [65]	train-logloss:0.243832	val-logloss:0.243785
# Round 66 update starts...
# Round 66 update: 2.52s
# Round 66 eval starts...
# Round 66 eval: 0.05s
# [66]	train-logloss:0.243556	val-logloss:0.24351
# Round 67 update starts...
# Round 67 update: 2.48s
# Round 67 eval starts...
# Round 67 eval: 0.05s
# [67]	train-logloss:0.243301	val-logloss:0.243257
# Round 68 update starts...
# Round 68 update: 2.57s
# Round 68 eval starts...
# Round 68 eval: 0.05s
# [68]	train-logloss:0.243064	val-logloss:0.243022
# Round 69 update starts...
# Round 69 update: 2.51s
# Round 69 eval starts...
# Round 69 eval: 0.05s
# [69]	train-logloss:0.242845	val-logloss:0.242804
# Round 70 update starts...
# Round 70 update: 2.51s
# Round 70 eval starts...
# Round 70 eval: 0.05s
# [70]	train-logloss:0.242642	val-logloss:0.242603
# Round 71 update starts...
# Round 71 update: 2.48s
# Round 71 eval starts...
# Round 71 eval: 0.05s
# [71]	train-logloss:0.242454	val-logloss:0.242418
# Round 72 update starts...
# Round 72 update: 2.46s
# Round 72 eval starts...
# Round 72 eval: 0.05s
# [72]	train-logloss:0.24228	val-logloss:0.242245
# Round 73 update starts...
# Round 73 update: 2.52s
# Round 73 eval starts...
# Round 73 eval: 0.05s
# [73]	train-logloss:0.242119	val-logloss:0.242085
# Round 74 update starts...
# Round 74 update: 2.54s
# Round 74 eval starts...
# Round 74 eval: 0.05s
# [74]	train-logloss:0.241971	val-logloss:0.24194
# Round 75 update starts...
# Round 75 update: 2.44s
# Round 75 eval starts...
# Round 75 eval: 0.05s
# [75]	train-logloss:0.241834	val-logloss:0.241804
# Round 76 update starts...
# Round 76 update: 2.49s
# Round 76 eval starts...
# Round 76 eval: 0.05s
# [76]	train-logloss:0.241706	val-logloss:0.241679
# Round 77 update starts...
# Round 77 update: 2.41s
# Round 77 eval starts...
# Round 77 eval: 0.05s
# [77]	train-logloss:0.241588	val-logloss:0.241563
# Round 78 update starts...
# Round 78 update: 2.44s
# Round 78 eval starts...
# Round 78 eval: 0.05s
# [78]	train-logloss:0.24148	val-logloss:0.241455
# Round 79 update starts...
# Round 79 update: 2.48s
# Round 79 eval starts...
# Round 79 eval: 0.05s
# [79]	train-logloss:0.241379	val-logloss:0.241356
# Round 80 update starts...
# Round 80 update: 2.46s
# Round 80 eval starts...
# Round 80 eval: 0.05s
# [80]	train-logloss:0.241286	val-logloss:0.241265
# Round 81 update starts...
# Round 81 update: 2.44s
# Round 81 eval starts...
# Round 81 eval: 0.05s
# [81]	train-logloss:0.2412	val-logloss:0.241181
# Round 82 update starts...
# Round 82 update: 2.49s
# Round 82 eval starts...
# Round 82 eval: 0.05s
# [82]	train-logloss:0.241122	val-logloss:0.241105
# Round 83 update starts...
# Round 83 update: 2.44s
# Round 83 eval starts...
# Round 83 eval: 0.05s
# [83]	train-logloss:0.241049	val-logloss:0.241034
# Round 84 update starts...
# Round 84 update: 2.44s
# Round 84 eval starts...
# Round 84 eval: 0.05s
# [84]	train-logloss:0.240982	val-logloss:0.240969
# Round 85 update starts...
# Round 85 update: 2.37s
# Round 85 eval starts...
# Round 85 eval: 0.05s
# [85]	train-logloss:0.24092	val-logloss:0.240908
# Round 86 update starts...
# Round 86 update: 2.42s
# Round 86 eval starts...
# Round 86 eval: 0.05s
# [86]	train-logloss:0.240864	val-logloss:0.240854
# Round 87 update starts...
# Round 87 update: 2.42s
# Round 87 eval starts...
# Round 87 eval: 0.07s
# [87]	train-logloss:0.240811	val-logloss:0.240803
# Round 88 update starts...
# Round 88 update: 2.41s
# Round 88 eval starts...
# Round 88 eval: 0.05s
# [88]	train-logloss:0.240763	val-logloss:0.240756
# Round 89 update starts...
# Round 89 update: 2.45s
# Round 89 eval starts...
# Round 89 eval: 0.05s
# [89]	train-logloss:0.240718	val-logloss:0.240713
# Round 90 update starts...
# Round 90 update: 2.37s
# Round 90 eval starts...
# Round 90 eval: 0.05s
# [90]	train-logloss:0.240677	val-logloss:0.240674
# Round 91 update starts...
# Round 91 update: 2.43s
# Round 91 eval starts...
# Round 91 eval: 0.05s
# [91]	train-logloss:0.240639	val-logloss:0.240637
# Round 92 update starts...
# Round 92 update: 2.38s
# Round 92 eval starts...
# Round 92 eval: 0.05s
# [92]	train-logloss:0.240604	val-logloss:0.240602
# Round 93 update starts...
# Round 93 update: 2.42s
# Round 93 eval starts...
# Round 93 eval: 0.05s
# [93]	train-logloss:0.240572	val-logloss:0.240572
# Round 94 update starts...
# Round 94 update: 2.34s
# Round 94 eval starts...
# Round 94 eval: 0.05s
# [94]	train-logloss:0.240542	val-logloss:0.240544
# Round 95 update starts...
# Round 95 update: 2.35s
# Round 95 eval starts...
# Round 95 eval: 0.05s
# [95]	train-logloss:0.240515	val-logloss:0.240519
# Round 96 update starts...
# Round 96 update: 2.39s
# Round 96 eval starts...
# Round 96 eval: 0.05s
# [96]	train-logloss:0.240491	val-logloss:0.240496
# Round 97 update starts...
# Round 97 update: 2.36s
# Round 97 eval starts...
# Round 97 eval: 0.05s
# [97]	train-logloss:0.240468	val-logloss:0.240475
# Round 98 update starts...
# Round 98 update: 2.42s
# Round 98 eval starts...
# Round 98 eval: 0.05s
# [98]	train-logloss:0.240447	val-logloss:0.240455
# Round 99 update starts...
# Round 99 update: 2.36s
# Round 99 eval starts...
# Round 99 eval: 0.05s
# [99]	train-logloss:0.240428	val-logloss:0.240436
# Round 100 update starts...
# Round 100 update: 2.30s
# Round 100 eval starts...
# Round 100 eval: 0.08s
# [100]	train-logloss:0.24041	val-logloss:0.24042
# Round 101 update starts...
# Round 101 update: 2.24s
# Round 101 eval starts...
# Round 101 eval: 0.05s
# [101]	train-logloss:0.240393	val-logloss:0.240405
# Round 102 update starts...
# Round 102 update: 2.32s
# Round 102 eval starts...
# Round 102 eval: 0.05s
# [102]	train-logloss:0.240378	val-logloss:0.240391
# Round 103 update starts...
# Round 103 update: 2.33s
# Round 103 eval starts...
# Round 103 eval: 0.05s
# [103]	train-logloss:0.240364	val-logloss:0.240378
# Round 104 update starts...
# Round 104 update: 2.22s
# Round 104 eval starts...
# Round 104 eval: 0.05s
# [104]	train-logloss:0.240351	val-logloss:0.240367
# Round 105 update starts...
# Round 105 update: 2.26s
# Round 105 eval starts...
# Round 105 eval: 0.05s
# [105]	train-logloss:0.240339	val-logloss:0.240357
# Round 106 update starts...
# Round 106 update: 2.26s
# Round 106 eval starts...
# Round 106 eval: 0.05s
# [106]	train-logloss:0.240328	val-logloss:0.240346
# Round 107 update starts...
# Round 107 update: 2.21s
# Round 107 eval starts...
# Round 107 eval: 0.08s
# [107]	train-logloss:0.240318	val-logloss:0.240337
# Round 108 update starts...
# Round 108 update: 2.19s
# Round 108 eval starts...
# Round 108 eval: 0.05s
# [108]	train-logloss:0.240309	val-logloss:0.240329
# Round 109 update starts...
# Round 109 update: 2.27s
# Round 109 eval starts...
# Round 109 eval: 0.05s
# [109]	train-logloss:0.2403	val-logloss:0.240322
# Round 110 update starts...
# Round 110 update: 2.16s
# Round 110 eval starts...
# Round 110 eval: 0.08s
# [110]	train-logloss:0.240292	val-logloss:0.240316
# Round 111 update starts...
# Round 111 update: 2.22s
# Round 111 eval starts...
# Round 111 eval: 0.08s
# [111]	train-logloss:0.240285	val-logloss:0.240308
# Round 112 update starts...
# Round 112 update: 2.14s
# Round 112 eval starts...
# Round 112 eval: 0.05s
# [112]	train-logloss:0.240278	val-logloss:0.240303
# Round 113 update starts...
# Round 113 update: 2.17s
# Round 113 eval starts...
# Round 113 eval: 0.05s
# [113]	train-logloss:0.240272	val-logloss:0.240299
# Round 114 update starts...
# Round 114 update: 2.26s
# Round 114 eval starts...
# Round 114 eval: 0.05s
# [114]	train-logloss:0.240266	val-logloss:0.240294
# Round 115 update starts...
# Round 115 update: 2.30s
# Round 115 eval starts...
# Round 115 eval: 0.08s
# [115]	train-logloss:0.240261	val-logloss:0.24029
# Round 116 update starts...
# Round 116 update: 2.23s
# Round 116 eval starts...
# Round 116 eval: 0.05s
# [116]	train-logloss:0.240256	val-logloss:0.240286
# Round 117 update starts...
# Round 117 update: 2.21s
# Round 117 eval starts...
# Round 117 eval: 0.05s
# [117]	train-logloss:0.240251	val-logloss:0.240284
# Round 118 update starts...
# Round 118 update: 2.23s
# Round 118 eval starts...
# Round 118 eval: 0.05s
# [118]	train-logloss:0.240247	val-logloss:0.240281
# Round 119 update starts...
# Round 119 update: 2.34s
# Round 119 eval starts...
# Round 119 eval: 0.05s
# [119]	train-logloss:0.240243	val-logloss:0.240279
# Round 120 update starts...
# Round 120 update: 2.20s
# Round 120 eval starts...
# Round 120 eval: 0.09s
# [120]	train-logloss:0.240239	val-logloss:0.240277
# Round 121 update starts...
# Round 121 update: 2.20s
# Round 121 eval starts...
# Round 121 eval: 0.07s
# [121]	train-logloss:0.240236	val-logloss:0.240275
# Round 122 update starts...
# Round 122 update: 2.23s
# Round 122 eval starts...
# Round 122 eval: 0.05s
# [122]	train-logloss:0.240232	val-logloss:0.240272
# Round 123 update starts...
# Round 123 update: 2.25s
# Round 123 eval starts...
# Round 123 eval: 0.05s
# [123]	train-logloss:0.240229	val-logloss:0.240269
# Round 124 update starts...
# Round 124 update: 2.12s
# Round 124 eval starts...
# Round 124 eval: 0.05s
# [124]	train-logloss:0.240227	val-logloss:0.240267
# Round 125 update starts...
# Round 125 update: 2.04s
# Round 125 eval starts...
# Round 125 eval: 0.05s
# [125]	train-logloss:0.240224	val-logloss:0.240265
# Round 126 update starts...
# Round 126 update: 2.10s
# Round 126 eval starts...
# Round 126 eval: 0.08s
# [126]	train-logloss:0.240222	val-logloss:0.240264
# Round 127 update starts...
# Round 127 update: 2.07s
# Round 127 eval starts...
# Round 127 eval: 0.05s
# [127]	train-logloss:0.240219	val-logloss:0.240262
# Round 128 update starts...
# Round 128 update: 2.07s
# Round 128 eval starts...
# Round 128 eval: 0.05s
# [128]	train-logloss:0.240217	val-logloss:0.240261
# Round 129 update starts...
# Round 129 update: 2.09s
# Round 129 eval starts...
# Round 129 eval: 0.05s
# [129]	train-logloss:0.240215	val-logloss:0.240259
# Round 130 update starts...
# Round 130 update: 2.06s
# Round 130 eval starts...
# Round 130 eval: 0.08s
# [130]	train-logloss:0.240213	val-logloss:0.240258
# Round 131 update starts...
# Round 131 update: 2.11s
# Round 131 eval starts...
# Round 131 eval: 0.05s
# [131]	train-logloss:0.240211	val-logloss:0.240257
# Round 132 update starts...
# Round 132 update: 2.04s
# Round 132 eval starts...
# Round 132 eval: 0.05s
# [132]	train-logloss:0.240209	val-logloss:0.240256
# Round 133 update starts...
# Round 133 update: 2.14s
# Round 133 eval starts...
# Round 133 eval: 0.05s
# [133]	train-logloss:0.240207	val-logloss:0.240255
# Round 134 update starts...
# Round 134 update: 1.94s
# Round 134 eval starts...
# Round 134 eval: 0.05s
# [134]	train-logloss:0.240206	val-logloss:0.240254
# Round 135 update starts...
# Round 135 update: 2.04s
# Round 135 eval starts...
# Round 135 eval: 0.08s
# [135]	train-logloss:0.240204	val-logloss:0.240254
# Round 136 update starts...
# Round 136 update: 2.10s
# Round 136 eval starts...
# Round 136 eval: 0.08s
# [136]	train-logloss:0.240202	val-logloss:0.240253
# Round 137 update starts...
# Round 137 update: 2.14s
# Round 137 eval starts...
# Round 137 eval: 0.08s
# [137]	train-logloss:0.240201	val-logloss:0.240252
# Round 138 update starts...
# Round 138 update: 2.08s
# Round 138 eval starts...
# Round 138 eval: 0.08s
# [138]	train-logloss:0.240199	val-logloss:0.240252
# Round 139 update starts...
# Round 139 update: 1.89s
# Round 139 eval starts...
# Round 139 eval: 0.05s
# [139]	train-logloss:0.240198	val-logloss:0.240252
# Round 140 update starts...
# Round 140 update: 2.13s
# Round 140 eval starts...
# Round 140 eval: 0.08s
# [140]	train-logloss:0.240197	val-logloss:0.240253
# Round 141 update starts...
# Round 141 update: 1.95s
# Round 141 eval starts...
# Round 141 eval: 0.05s
# [141]	train-logloss:0.240196	val-logloss:0.240253
# Round 142 update starts...
# Round 142 update: 1.86s
# Round 142 eval starts...
# Round 142 eval: 0.05s
# [142]	train-logloss:0.240194	val-logloss:0.240252
# Round 143 update starts...
# Round 143 update: 1.91s
# Round 143 eval starts...
# Round 143 eval: 0.05s
# [143]	train-logloss:0.240193	val-logloss:0.240251
# Round 144 update starts...
# Round 144 update: 1.91s
# Round 144 eval starts...
# Round 144 eval: 0.09s
# [144]	train-logloss:0.240192	val-logloss:0.24025
# Round 145 update starts...
# Round 145 update: 2.06s
# Round 145 eval starts...
# Round 145 eval: 0.08s
# [145]	train-logloss:0.240191	val-logloss:0.24025
# Round 146 update starts...
# Round 146 update: 2.07s
# Round 146 eval starts...
# Round 146 eval: 0.08s
# [146]	train-logloss:0.24019	val-logloss:0.24025
# Round 147 update starts...
# Round 147 update: 1.96s
# Round 147 eval starts...
# Round 147 eval: 0.08s
# [147]	train-logloss:0.240189	val-logloss:0.240249
# Round 148 update starts...
# Round 148 update: 1.95s
# Round 148 eval starts...
# Round 148 eval: 0.05s
# [148]	train-logloss:0.240188	val-logloss:0.240249
# Round 149 update starts...
